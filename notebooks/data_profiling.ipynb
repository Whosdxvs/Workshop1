# %% [markdown]
# # Initial Data Profiling
#
# This notebook contains the basic profiling of the candidates dataset as required in Task 1.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('../data/raw/candidates.csv', sep=';')
df.head()

# %% [markdown]
# ### Basic Info and Nulls

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# ### Duplicates

# %%
df.duplicated().sum()

# %% [markdown]
# ### Descriptive Statistics

# %%
df.describe()

# %% [markdown]
# ### Unique Values and Dates

# %%
print("Min Date:", df['Application Date'].min())
print("Max Date:", df['Application Date'].max())
print("Technologies:", df['Technology'].unique())
print("Seniorities:", df['Seniority'].unique())
